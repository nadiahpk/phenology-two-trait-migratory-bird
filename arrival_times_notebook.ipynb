# %% [markdown]
# Hello world, for the paper go to [the paper](http://nadiah.org).
#
#
#     PS this is a markdown cell.
#
# I can render $1 + x + \sum_{0}^nx_i$ inline maths!
#
# Or big equations too:
#
# $$
# 1 + 1 = 2 + \theta + \sum_{0}^nx_i + \xi + \eta
# $$

# %%
# %matplotlib inline

from ipywidgets import StaticInteract, RangeWidget
from arrivaltimeslider import plot, U_Q_MIN, U_Q_MAX, U_Q_STEP

StaticInteract(plot, u_q=RangeWidget(U_Q_MIN, U_Q_MAX, U_Q_STEP))
# Out:
#     <script type="text/javascript">
#       function interactUpdate(div){
#          var outputs = div.getElementsByTagName("div");
#          var controls = div.getElementsByTagName("input");
#
#          var value = "";
#          for(i=0; i<controls.length; i++){
#            if((controls[i].type == "range") || controls[i].checked){
#              value = value + controls[i].getAttribute("name") + controls[i].value;
#            }
#          }
#
#          for(i=0; i<outputs.length; i++){
#            var name = outputs[i].getAttribute("name");
#            if(name == value){
#               outputs[i].style.display = 'block';
#            } else if(name != "controls"){
#               outputs[i].style.display = 'none';
#            }
#          }
#       }
#     </script>
#
#     <div>
#
#     <div name="u_q125" style="display:block">
#       <img src="...">
#     </div>
#
#     <div name="u_q126" style="display:none">
#       <img src="...
